# %% [markdown]
# # TensorFlow Chess engine
#
#  ### Dataset

# %%
import os

files = [file for file in os.listdir("../Database") if file.endswith('.pgn')]

# %%
len(files)
# Out:
# 110

# %%
from chess import pgn

def load_pgn(file_path):
    games = []
    with open(file_path, 'r') as file:
        while True:
            game = pgn.read_game(file)
            if game is None:
                break
            games.append(game)
    return games

# %%
from tqdm import tqdm

LIMIT_OF_FILES = min(len(files), 12)
games = []

i = 1

for file in tqdm(files):
    games.extend(load_pgn(f"../Database/{file}"))
    if (i >= LIMIT_OF_FILES):
        break

    i+=1
# Out:
#  10%|█         | 11/110 [00:04<00:41,  2.37it/s]

# %%
len(games)
# Out:
# 1341

# %% [markdown]
# # Build & Train a neural network

# %%
import numpy as np
from chess import Board
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import pickle

# %%
def board_to_matrix(board: Board):
    matrix = np.zeros((8, 8, 12))
    piece_map = board.piece_map()
    for square, piece in piece_map.items():
        row,col = divmod(square, 8)
        piece_type = piece.piece_type -1
        piece_color = 0 if piece.color else 6
        matrix[row, col, piece_type + piece_color] = 1
    return matrix

def create_input_for_nn(games):
    X=[]
    y = []
    for game in games:
        board = game.board()
        for move in game.mainline_moves():
            X.append(board_to_matrix(board))
            y.append(move.uci())
            board.push(move)
    return X,y

def encode_moves (moves):
    move_to_int = {move: i for i, move in enumerate(set(moves))}
    return [move_to_int[move] for move in moves], move_to_int

# %%
X,y = create_input_for_nn(games)
y, move_to_int = encode_moves(y)
y = to_categorical(y, num_classes=len(move_to_int))
X = np.array(X)

# %%
if os.path.exists('../model/chess_model.keras'):
    model = tf.keras.models.load_model('../model/tensorflow/chess_model_tensorflow.keras')
else:                                                                              
    model = Sequential([
        Conv2D(64, (3, 3), activation='relu', input_shape=(8, 8, 12)),
        Conv2D(128, (3, 3), activation='relu'),
        Flatten(),
        Dense(256, activation='relu'),
        Dense(len(move_to_int), activation='softmax')
    ])
    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
model.fit(X, y, epochs=50, batch_size=64, validation_split=0.1)
if not os.path.exists('../model'):
    os.makedirs('../model')
model.save('../model/tensorflowchess_model_tensorflow.keras')


# Save move_to_int dictionary
with open('../model/tensorflow/move_to_int.pkl', 'wb') as f:
    pickle.dump(move_to_int, f)
# Out:
# C:\Users\Ricar\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 6, 6, 64)       │         6,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 4, 4, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1815)           │       466,455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,071,831 (4.09 MB)
#  Trainable params: 1,071,831 (4.09 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 45s 26ms/step - accuracy: 0.0376 - loss: 6.4072 - val_accuracy: 0.0840 - val_loss: 5.7880
# Epoch 2/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 52s 33ms/step - accuracy: 0.1091 - loss: 5.4403 - val_accuracy: 0.1118 - val_loss: 5.3597
# Epoch 3/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 65s 41ms/step - accuracy: 0.1516 - loss: 4.7291 - val_accuracy: 0.1221 - val_loss: 5.2191
# Epoch 4/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 135s 84ms/step - accuracy: 0.1898 - loss: 4.1433 - val_accuracy: 0.1196 - val_loss: 5.2739
# Epoch 5/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 74s 46ms/step - accuracy: 0.2307 - loss: 3.6752 - val_accuracy: 0.1283 - val_loss: 5.3621
# Epoch 6/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 58s 31ms/step - accuracy: 0.2768 - loss: 3.2839 - val_accuracy: 0.1225 - val_loss: 5.6159
# Epoch 7/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 49s 31ms/step - accuracy: 0.3210 - loss: 2.9614 - val_accuracy: 0.1271 - val_loss: 5.9100
# Epoch 8/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 48s 30ms/step - accuracy: 0.3678 - loss: 2.6674 - val_accuracy: 0.1256 - val_loss: 6.1313
# Epoch 9/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━
50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 60s 37ms/step - accuracy: 0.8277 - loss: 0.5659 - val_accuracy: 0.1126 - val_loss: 17.9250
# Epoch 37/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 73s 45ms/step - accuracy: 0.8327 - loss: 0.5496 - val_accuracy: 0.1074 - val_loss: 18.2220
# Epoch 38/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 64s 40ms/step - accuracy: 0.8335 - loss: 0.5400 - val_accuracy: 0.1128 - val_loss: 18.6811
# Epoch 39/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 79s 37ms/step - accuracy: 0.8405 - loss: 0.5226 - val_accuracy: 0.1108 - val_loss: 19.0509
# Epoch 40/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 96s 46ms/step - accuracy: 0.8401 - loss: 0.5231 - val_accuracy: 0.1126 - val_loss: 19.4245
# Epoch 41/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 82s 51ms/step - accuracy: 0.8436 - loss: 0.5099 - val_accuracy: 0.1145 - val_loss: 19.5554
# Epoch 42/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 64s 40ms/step - accuracy: 0.8447 - loss: 0.5035 - val_accuracy: 0.1134 - val_loss: 20.1870
# Epoch 43/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 68s 42ms/step - accuracy: 0.8465 - loss: 0.5004 - val_accuracy: 0.1129 - val_loss: 20.4275
# Epoch 44/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 57s 35ms/step - accuracy: 0.8511 - loss: 0.4911 - val_accuracy: 0.1098 - val_loss: 20.3637
# Epoch 45/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 53s 33ms/step - accuracy: 0.8547 - loss: 0.4803 - val_accuracy: 0.1130 - val_loss: 20.6588
# Epoch 46/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 50s 31ms/step - accuracy: 0.8543 - loss: 0.4748 - val_accuracy: 0.1148 - val_loss: 21.3323
# Epoch 47/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 48s 30ms/step - accuracy: 0.8529 - loss: 0.4775 - val_accuracy: 0.1133 - val_loss: 21.6045
# Epoch 48/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 91s 35ms/step - accuracy: 0.8566 - loss: 0.4682 - val_accuracy: 0.1116 - val_loss: 21.6942
# Epoch 49/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 48s 30ms/step - accuracy: 0.8618 - loss: 0.4579 - val_accuracy: 0.1124 - val_loss: 22.0462
# Epoch 50/50
# 1606/1606 ━━━━━━━━━━━━━━━━━━━━ 58s 36ms/step - accuracy: 0.8572 - loss: 0.4660 - val_accuracy: 0.1124 - val_loss: 22.0672

# %%
from tensorflow.keras.models import load_model
model = load_model('../model/tensorflow/chess_model_tensorflow.keras')

if not move_to_int:
    with open('../model/tensorflow/move_to_int.pkl', 'rb') as f:
        move_to_int = pickle.load(f)

# %%
int_to_move = dict(zip(move_to_int.values(), move_to_int.keys()))

def predict_move(board):
    board_matrix = board_to_matrix(board).reshape(1, 8, 8, 12)
    predictions = model.predict(board_matrix)[0]
    legal_moves = list(board.legal_moves)
    uci_legal = [move.uci() for move in legal_moves]
    move_index = np.argsort(predictions)[::-1]
    for move_index in move_index:
        move = int_to_move[move_index]
        if move in uci_legal:
            return move
    return None

# %%
board = Board()

# %%
print("Board before prediction: ")
board

# Predict move
while not board.is_game_over():
    move = predict_move(board)
    board.push_uci(move)

    print("Predicted move: ", move)
    print("Board after prediction: ")
    board
    
print(str(pgn.Game.from_board(board)))
# Out:
# Board before prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# Predicted move:  e2e4
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Predicted move:  d7d5
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Predicted move:  e4d5
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Predicted move:  d8d5
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Predicted move:  g1f3
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Predicted move:  b8c6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Predicted move:  f1e2
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Predicted move:  c8g4
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Predicted move:  h2h3
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Predicted move:  g4f3
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted move:  e2f3
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# Predicted move:  d5d7
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Predicted move:  e1g1
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 814ms/step
# Predicted move:  e8c8
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Predicted move:  f1e1
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Predicted move:  e7e5
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Predicted move:  b1c3
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Predicted move:  f8d6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Predicted move:  b2b4
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# Predicted move:  f7f5
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted move:  f3c6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Predicted move:  d7c6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted move:  b4b5
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Predicted move:  c6d7
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Predicted move:  d2d3
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted move:  g8f6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Predicted move:  c1e3
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Predicted move:  c8b8
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Predicted move:  a2a4
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Predicted move:  d6b4
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Predicted move:  e3d2
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Predicted move:  e5e4
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Predicted move:  c3e4
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# Predicted move:  f5e4
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Predicted move:  d2b4
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Predicted move:  e4d3
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Predicted move:  c2d3
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Predicted move:  d7d3
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Predicted move:  b4e7
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Predicted move:  d3d1
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Predicted move:  a1d1
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Predicted move:  d8d1
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Predicted move:  e1d1
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Predicted move:  b8c8
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Predicted move:  g2g4
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Predicted move:  h7h6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Predicted move:  e7f6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Predicted move:  g7f6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Predicted move:  g1h2
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Predicted move:  a7a6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Predicted move:  f2f3
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Predicted move:  a6b5
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Predicted move:  a4b5
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# Predicted move:  c7c6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Predicted move:  d1d7
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Predicted move:  c8d7
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Predicted move:  f3f4
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Predicted move:  c6c5
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Predicted move:  g4g5
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Predicted move:  h6g5
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Predicted move:  h2h1
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Predicted move:  c5c4
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Predicted move:  f4f5
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Predicted move:  h8f8
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Predicted move:  h3h4
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Predicted move:  f8e8
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Predicted move:  h4g5
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Predicted move:  e8h8
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Predicted move:  h1g1
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Predicted move:  h8g8
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Predicted move:  g5g6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Predicted move:  d7c7
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Predicted move:  g1h1
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Predicted move:  c7b6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Predicted move:  g6g7
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Predicted move:  c4c3
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Predicted move:  h1h2
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Predicted move:  g8g7
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# Predicted move:  h2h3
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Predicted move:  b6c7
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Predicted move:  h3h4
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Predicted move:  c7b6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# Predicted move:  h4h5
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Predicted move:  b6c7
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Predicted move:  h5h6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Predicted move:  c3c2
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Predicted move:  h6h5
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Predicted move:  c7b6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Predicted move:  h5h6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Predicted move:  b6c7
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Predicted move:  h6h5
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Predicted move:  c7b6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Predicted move:  h5h6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Predicted move:  b6c7
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Predicted move:  h6h5
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Predicted move:  c7b6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Predicted move:  h5h6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Predicted move:  b6c7
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Predicted move:  h6h5
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Predicted move:  c7b6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Predicted move:  h5h6
# Board after prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Predicted move:  b6c7
# Board after prediction:
# [Event "?"]
# [Site "?"]
# [Date "????.??.??"]
# [Round "?"]
# [White "?"]
# [Black "?"]
# [Result "1/2-1/2"]
#
# 1. e4 d5 2. exd5 Qxd5 3. Nf3 Nc6 4. Be2 Bg4 5. h3 Bxf3 6. Bxf3 Qd7 7. O-O O-O-O 8. Re1 e5 9. Nc3 Bd6 10. b4 f5 11. Bxc6 Qxc6 12. b5 Qd7 13. d3 Nf6 14. Be3 Kb8 15. a4 Bb4 16. Bd2 e4 17. Nxe4 fxe4 18. Bxb4 exd3 19. cxd3 Qxd3 20. Be7 Qxd1 21. Raxd1 Rxd1 22. Rxd1 Kc8 23. g4 h6 24. Bxf6 gxf6 25. Kh2 a6 26. f3 axb5 27. axb5 c6 28. Rd7 Kxd7 29. f4 c5 30. g5 hxg5 31. Kh1 c4 32. f5 Rf8 33. h4 Re8 34. hxg5 Rh8+ 35. Kg1 Rg8 36. g6 Kc7 37. Kh1 Kb6 38. g7 c3 39. Kh2 Rxg7 40. Kh3 Kc7 41. Kh4 Kb6 42. Kh5 Kc7 43. Kh6 c2 44. Kh5 Kb6 45. Kh6 Kc7 46. Kh5 Kb6 47. Kh6 Kc7 48. Kh5 Kb6 49. Kh6 Kc7 50. Kh5 Kb6 51. Kh6 Kc7 1/2-1/2
